# %% [markdown]
# ## View_1

# %%
import matplotlib.pyplot as plt
import numpy as np

# Dados
tempo_otimizado = [4006.436, 3469.934, 3807.397, 3546.667, 2991.566, 3036.579]
tempo_nao_otimizado = [3284.657, 3166.449, 3136.728, 3127.309, 3126.416, 3261.720]
labels = ['Tentativa 1', 'Tentativa 2', 'Tentativa 3', 'Tentativa 4', 'Tentativa 5', 'Tentativa 6']

# Configurações do gráfico
x = np.arange(len(labels))
width = 0.35

fig, ax = plt.subplots(figsize=(12, 8))  # Ajuste no tamanho do gráfico
rects1 = ax.bar(x - width/2, tempo_otimizado, width, label='Tempo Otimizado', color='#4169e1')
rects2 = ax.bar(x + width/2, tempo_nao_otimizado, width, label='Tempo Não Otimizado', color='#ff0000')

# Adicionando textos e etiquetas
ax.set_xlabel('Conjuntos de Dados')
ax.set_ylabel('Tempo (em segundos)')
ax.set_title('Comparação de Tempo Otimizado e Não Otimizado por Conjunto de Dados')
ax.set_xticks(x)
ax.set_xticklabels(labels, rotation=45)  # Rotacionando os rótulos
ax.legend()

# Função para adicionar uma etiqueta de valor em cada coluna
def autolabel(rects):
    for rect in rects:
        height = rect.get_height()
        ax.annotate('{:.1f}'.format(height),  # Formatação dos números
                    xy=(rect.get_x() + rect.get_width() / 2, height),
                    xytext=(0, 10),  # Deslocamento vertical aumentado
                    textcoords="offset points",
                    ha='center', va='bottom', fontsize=8)  # Tamanho de fonte reduzido

autolabel(rects1)
autolabel(rects2)

fig.tight_layout()

# Mostrando o gráfico
plt.show()

# %% [markdown]
# # V2_VIEWS

# %%
import matplotlib.pyplot as plt
import numpy as np

# Dados
tempo_otimizado = [3678.173, 3333.157, 3237.819, 3432.503, 3302.879, 3365.855]
tempo_nao_otimizado = [4828.833, 4928.568, 4700.565, 4768.998, 4684.034, 4984.562]
labels = ['Tentativa 1', 'Tentativa 2', 'Tentativa 3', 'Tentativa 4', 'Tentativa 5', 'Tentativa 6']

# Configurações do gráfico
x = np.arange(len(labels))
width = 0.35

fig, ax = plt.subplots(figsize=(12, 8))  # Ajuste no tamanho do gráfico
rects1 = ax.bar(x - width/2, tempo_otimizado, width, label='Tempo Otimizado', color='#4169e1')
rects2 = ax.bar(x + width/2, tempo_nao_otimizado, width, label='Tempo Não Otimizado', color='#ff0000')

# Adicionando textos e etiquetas
ax.set_xlabel('Conjuntos de Dados')
ax.set_ylabel('Tempo (em segundos)')
ax.set_title('Comparação de Tempo Otimizado e Não Otimizado por Conjunto de Dados')
ax.set_xticks(x)
ax.set_xticklabels(labels, rotation=45)  # Rotacionando os rótulos
ax.legend()

# Função para adicionar uma etiqueta de valor em cada coluna
def autolabel(rects):
    for rect in rects:
        height = rect.get_height()
        ax.annotate('{:.1f}'.format(height),  # Formatação dos números
                    xy=(rect.get_x() + rect.get_width() / 2, height),
                    xytext=(0, 10),  # Deslocamento vertical aumentado
                    textcoords="offset points",
                    ha='center', va='bottom', fontsize=8)  # Tamanho de fonte reduzido

autolabel(rects1)
autolabel(rects2)

fig.tight_layout()

# Mostrando o gráfico
plt.show()

# %% [markdown]
# # V3_VIEW

# %%
import matplotlib.pyplot as plt
import numpy as np

# Dados
tempo_otimizado = [4151.617, 4275.061, 4235.187, 4311.983, 4348.021, 4247.527]
tempo_nao_otimizado = [18012.199, 18185.170, 17917.919, 18798.752, 18890.057, 19178.121]
labels = ['Tentativa 1', 'Tentativa 2', 'Tentativa 3', 'Tentativa 4', 'Tentativa 5', 'Tentativa 6']

# Configurações do gráfico
x = np.arange(len(labels))
width = 0.35

fig, ax = plt.subplots(figsize=(12, 8))  # Ajuste no tamanho do gráfico
rects1 = ax.bar(x - width/2, tempo_otimizado, width, label='Tempo Otimizado', color='#4169e1')
rects2 = ax.bar(x + width/2, tempo_nao_otimizado, width, label='Tempo Não Otimizado', color='#ff0000')

# Adicionando textos e etiquetas
ax.set_xlabel('Conjuntos de Dados')
ax.set_ylabel('Tempo (em segundos)')
ax.set_title('Comparação de Tempo Otimizado e Não Otimizado por Conjunto de Dados')
ax.set_xticks(x)
ax.set_xticklabels(labels, rotation=45)  # Rotacionando os rótulos
ax.legend()

# Função para adicionar uma etiqueta de valor em cada coluna
def autolabel(rects):
    for rect in rects:
        height = rect.get_height()
        ax.annotate('{:.1f}'.format(height),  # Formatação dos números
                    xy=(rect.get_x() + rect.get_width() / 2, height),
                    xytext=(0, 10),  # Deslocamento vertical aumentado
                    textcoords="offset points",
                    ha='center', va='bottom', fontsize=8)  # Tamanho de fonte reduzido

autolabel(rects1)
autolabel(rects2)

fig.tight_layout()

# Mostrando o gráfico
plt.show()

# %% [markdown]
# # V4 VIEW

# %%
import matplotlib.pyplot as plt
import numpy as np

# Dados
tempo_otimizado = [359.053, 245.699, 264.949, 263.174, 235.142, 314.582]
tempo_nao_otimizado = [323.831, 335.730, 359.918, 367.912, 369.568, 307.175]
labels = ['Tentativa 1', 'Tentativa 2', 'Tentativa 3', 'Tentativa 4', 'Tentativa 5', 'Tentativa 6']

# Configurações do gráfico
x = np.arange(len(labels))
width = 0.35

fig, ax = plt.subplots(figsize=(12, 8))  # Ajuste no tamanho do gráfico
rects1 = ax.bar(x - width/2, tempo_otimizado, width, label='Tempo Otimizado', color='#4169e1')
rects2 = ax.bar(x + width/2, tempo_nao_otimizado, width, label='Tempo Não Otimizado', color='#ff0000')

# Adicionando textos e etiquetas
ax.set_xlabel('Conjuntos de Dados')
ax.set_ylabel('Tempo (em segundos)')
ax.set_title('Comparação de Tempo Otimizado e Não Otimizado por Conjunto de Dados')
ax.set_xticks(x)
ax.set_xticklabels(labels, rotation=45)  # Rotacionando os rótulos
ax.legend()

# Função para adicionar uma etiqueta de valor em cada coluna
def autolabel(rects):
    for rect in rects:
        height = rect.get_height()
        ax.annotate('{:.1f}'.format(height),  # Formatação dos números
                    xy=(rect.get_x() + rect.get_width() / 2, height),
                    xytext=(0, 10),  # Deslocamento vertical aumentado
                    textcoords="offset points",
                    ha='center', va='bottom', fontsize=8)  # Tamanho de fonte reduzido

autolabel(rects1)
autolabel(rects2)

fig.tight_layout()

# Mostrando o gráfico
plt.show()
